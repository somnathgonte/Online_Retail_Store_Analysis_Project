# %%
from pyspark.sql.functions import col, sum, when, isnull, coalesce, collect_set, mean, to_date,trim, cast, date_format

# %%
#Entrypoint 2.x
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName("Data Preprocessing").config("spark.master", "local") \
    .config("spark.sql.legacy.timeParserPolicy", "LEGACY").getOrCreate()


sc = spark.sparkContext

# %%
df = spark.read.csv(r"file:\\\D:\CDAC\Project\new_retail_data.csv",header=True,inferSchema=True)

# %%
df.printSchema()
# Out:
# root
#  |-- Transaction_ID: double (nullable = true)
#  |-- Customer_ID: double (nullable = true)
#  |-- Name: string (nullable = true)
#  |-- Email: string (nullable = true)
#  |-- Phone: double (nullable = true)
#  |-- Address: string (nullable = true)
#  |-- City: string (nullable = true)
#  |-- State: string (nullable = true)
#  |-- Zipcode: double (nullable = true)
#  |-- Country: string (nullable = true)
#  |-- Age: double (nullable = true)
#  |-- Gender: string (nullable = true)
#  |-- Income: string (nullable = true)
#  |-- Customer_Segment: string (nullable = true)
#  |-- Date: string (nullable = true)
#  |-- Year: double (nullable = true)
#  |-- Month: string (nullable = true)
#  |-- Time: string (nullable = true)
#  |-- Total_Purchases: double (nullable = true)
#  |-- Amount: double (nullable = true)
#  |-- Total_Amount: double (nullable = true)
#  |-- Product_Category: string (nullable = true)
#  |-- Product_Brand: string (nullable = true)
#  |-- Product_Type: string (nullable = true)
#  |-- Feedback: string (nullable = true)
#  |-- Shipping_Method: string (nullable = true)
#  |-- Payment_Method: string (nullable = true)
#  |-- Order_Status: string (nullable = true)
#  |-- Ratings: double (nullable = true)
#  |-- products: string (nullable = true)

# %%
#df.show(5,truncate=False,vertical=True)
# Out:
# -RECORD 0---------------------------------------
#  Transaction_ID   | 8691788.0
#  Customer_ID      | 37249.0
#  Name             | Michelle Harrington
#  Email            | Ebony39@gmail.com
#  Phone            | 1.414786801E9
#  Address          | 3959 Amanda Burgs
#  City             | Dortmund
#  State            | Berlin
#  Zipcode          | 77985.0
#  Country          | Germany
#  Age              | 21.0
#  Gender           | Male
#  Income           | Low
#  Customer_Segment | Regular
#  Date             | 9/18/2023
#  Year             | 2023.0
#  Month            | September
#  Time             | 22:03:55
#  Total_Purchases  | 3.0
#  Amount           | 108.0287567
#  Total_Amount     | 324.08627
#  Product_Category | Clothing
#  Product_Brand    | Nike
#  Product_Type     | Shorts
#  Feedback         | Excellent
#  Shipping_Method  | Same-Day
#  Payment_Method   | Debit Card
#  Order_Status     | Shipped
#  Ratings          | 5.0
#  products         | Cycling shorts
# -RECORD 1---------------------------------------
#  Transaction_ID   | 2174773.0
#  Customer_ID      | 69749.0
#  Name             | Kelsey Hill
#  Email            | Mark36@gmail.com
#  Phone            | 6.852899987E9
#  Address          | 82072 Dawn Centers
#  City             | Nottingham
#  State            | England
#  Zipcode          | 99071.0
#  Country          | UK
#  Age              | 19.0
#  Gender           | Female
#  Income           | Low
#  Customer_Segment | Premium
#  Date             | 12/31/2023
#  Year             | 2023.0
#  Month            | December
#  Time             | 8:42:04
#  Total_Purchases  | 2.0
#  Amount           | 403.3539073
#  Total_Amount     | 806.7078147
#  Product_Category | Electronics
#  Product_Brand    | Samsung
#  Product_Type     | Tablet
#  Feedback         | Excellent
#  Shipping_Method  | Standard
#  Payment_Method   | Credit Card
#  Order_Status     | Processing
#  Ratings          | 4.0
#  products         | Lenovo Tab
# -RECORD 2---------------------------------------
#  Transaction_ID   | 6679610.0
#  Customer_ID      | 30192.0
#  Name             | Scott Jensen
#  Email            | Shane85@gmail.com
#  Phone            | 8.362160449E9
#  Address          | 4133 Young Canyon
#  City             | Geelong
#  State            | New South Wales
#  Zipcode          | 75929.0
#  Country          | Australia
#  Age              | 48.0
#  Gender           | Male
#  Income           | Low
#  Customer_Segment | Regular
#  Date             | 4/26/2023
#  Year             | 2023.0
#  Month            | April
#  Time             | 4:06:29
#  Total_Purchases  | 3.0
#  Amount           | 354.4775997
#  Total_Amount     | 1063.432799
#  Product_Category | Books
#  Product_Brand    | Penguin Books
#  Product_Type     | Children's
#  Feedback         | Average
#  Shipping_Method  | Same-Day
#  Payment_Method   | Credit Card
#  Order_Status     | Processing
#  Ratings          | 2.0
#  products         | Sports equipment
# -RECORD 3---------------------------------------
#  Transaction_ID   | 7232460.0
#  Customer_ID      | 62101.0
#  Name             | Joseph Miller
#  Email            | Mary34@gmail.com
#  Phone            | 2.776751724E9
#  Address          | 8148 Thomas Creek Suite 100
#  City             | Edmonton
#  State            | Ontario
#  Zipcode          | 88420.0
#  Country          | Canada
#  Age              | 56.0
#  Gender           | Male
#  Income           | High
#  Customer_Segment | Premium
#  Date             | 5/8/2023
#  Year             | 2023.0
#  Month            | May
#  Time             | 14:55:17
#  Total_Purchases  | 7.0
#  Amount           | 352.4077173
#  Total_Amount     | 2466.854021
#  Product_Category | Home Decor
#  Product_Brand    | Home Depot
#  Product_Type     | Tools
#  Feedback         | Excellent
#  Shipping_Method  | Standard
#  Payment_Method   | PayPal
#  Order_Status     | Processing
#  Ratings          | 4.0
#  products         | Utility knife
# -RECORD 4---------------------------------------
#  Transaction_ID   | 4983775.0
#  Customer_ID      | 27901.0
#  Name             | Debra Coleman
#  Email            | Charles30@gmail.com
#  Phone            | 9.098267635E9
#  Address          | 5813 Lori Ports Suite 269
#  City             | Bristol
#  State            | England
#  Zipcode          | 48704.0
#  Country          | UK
#  Age              | 22.0
#  Gender           | Male
#  Income           | Low
#  Customer_Segment | Premium
#  Date             | 1/10/2024
#  Year             | 2024.0
#  Month            | January
#  Time             | 16:54:07
#  Total_Purchases  | 2.0
#  Amount           | 124.2765245
#  Total_Amount     | 248.5530491
#  Product_Category | Grocery
#  Product_Brand    | Nestle
#  Product_Type     | Chocolate
#  Feedback         | Bad
#  Shipping_Method  | Standard
#  Payment_Method   | Cash
#  Order_Status     | Shipped
#  Ratings          | 1.0
#  products         | Chocolate cookies
# only showing top 5 rows

# %%
#type(df)
# Out:
# pyspark.sql.dataframe.DataFrame

# %%
#print(df.columns)
# Out:
# ['Transaction_ID', 'Customer_ID', 'Name', 'Email', 'Phone', 'Address', 'City', 'State', 'Zipcode', 'Country', 'Age', 'Gender', 'Income', 'Customer_Segment', 'Date', 'Year', 'Month', 'Time', 'Total_Purchases', 'Amount', 'Total_Amount', 'Product_Category', 'Product_Brand', 'Product_Type', 'Feedback', 'Shipping_Method', 'Payment_Method', 'Order_Status', 'Ratings', 'products']

# %% [markdown]
# - Drop columns - ['Transaction_ID','Name', 'Email', 'Phone','Address','Zipcode','Year', 'Month','Time','Order_Status']
# - Handle Null values using mean - ['Age','Ratings']
# - Handle Null values by mapping - ['Product_Category', 'Product_Brand','City', 'State', 'Country']
# - Handle Null values by calculation - ['Total_Purchases', 'Amount', 'Total_Amount']
# - Handle Null values using mode - ['Gender','Income','Customer_Segment','Feedback', 'Shipping_Method', 'Payment_Method']

# %%
# Checking null values
#null_count = df.select([sum(col(c).isNull().cast("int")).alias(c) for c in df.columns])
#null_count.show(vertical=True)
# Out:
# -RECORD 0---------------
#  Transaction_ID   | 333
#  Customer_ID      | 308
#  Name             | 382
#  Email            | 347
#  Phone            | 362
#  Address          | 315
#  City             | 248
#  State            | 281
#  Zipcode          | 340
#  Country          | 271
#  Age              | 173
#  Gender           | 317
#  Income           | 290
#  Customer_Segment | 215
#  Date             | 359
#  Year             | 350
#  Month            | 273
#  Time             | 350
#  Total_Purchases  | 361
#  Amount           | 357
#  Total_Amount     | 350
#  Product_Category | 283
#  Product_Brand    | 281
#  Product_Type     | 0
#  Feedback         | 184
#  Shipping_Method  | 337
#  Payment_Method   | 297
#  Order_Status     | 235
#  Ratings          | 184
#  products         | 0

# %% [markdown]
# #### Drop columns - ['Transaction_ID','Name', 'Email', 'Phone','Address','Zipcode','Year', 'Month','Time','Order_Status']

# %%
# Drop Columns which are not required  
df_req = df.drop('Transaction_ID','Name', 'Email', 'Phone','Address','Zipcode','Year', 'Month','Time','Order_Status')

# %% [markdown]
# #### Handle Null values by mapping - ['City', 'State', 'Country','Product_Category', 'Product_Brand']

# %%
# Create a mapping of State to City where City is not null
City_mapping = df_req.filter(col('City').isNotNull()) \
    .select('State', 'City') \
    .distinct() \
    .groupBy('State') \
    .agg(collect_set('City').alias('City_Set'))

# Extract a single City from the set for each State
City_mapping = City_mapping.withColumn('City_Mapped', col('City_Set')[0])

# Join the original DataFrame with the mapping to fill null values
df_req = df_req.join(City_mapping, on='State', how='left') \
    .withColumn('City', coalesce(col('City'), col('City_Mapped'))) \
    .drop('City_Set', 'City_Mapped')

# Show the updated DataFrame
#df_req.select(sum(col('City').isNull().cast('int')).alias("City")).show()

# %%
#City_mapping.show(5)
# Out:
# +---------+--------------------+-------------+
# |    State|            City_Set|  City_Mapped|
# +---------+--------------------+-------------+
# |     Utah|[Oklahoma City, M...|Oklahoma City|
# |   Hawaii|[Oklahoma City, M...|Oklahoma City|
# |Minnesota|[Oklahoma City, M...|Oklahoma City|
# |     Ohio|[Oklahoma City, M...|Oklahoma City|
# | Arkansas|[Oklahoma City, M...|Oklahoma City|
# +---------+--------------------+-------------+
# only showing top 5 rows

# %%
# Create a mapping of State to Country where Country is not null
Country_mapping = df_req.filter(col('Country').isNotNull()) \
    .select('State', 'Country') \
    .distinct() \
    .groupBy('State') \
    .agg(collect_set('Country').alias('Country_Set'))

# Extract a single Country from the set for each State
Country_mapping = Country_mapping.withColumn('Country_Mapped', col('Country_Set')[0])

# Join the original DataFrame with the mapping to fill null values
df_req = df_req.join(Country_mapping, on='State', how='left') \
    .withColumn('Country', coalesce(col('Country'), col('Country_Mapped'))) \
    .drop('Country_Set', 'Country_Mapped')

# Show the updated DataFrame
#df_req.select(sum(col('Country').isNull().cast('int')).alias("Country")).show()

# %%
#Country_mapping.show(5)
# Out:
# +---------+-----------+--------------+
# |    State|Country_Set|Country_Mapped|
# +---------+-----------+--------------+
# |     Utah|      [USA]|           USA|
# |   Hawaii|      [USA]|           USA|
# |Minnesota|      [USA]|           USA|
# |     Ohio|      [USA]|           USA|
# | Arkansas|      [USA]|           USA|
# +---------+-----------+--------------+
# only showing top 5 rows

# %%
# Create a mapping of Country to State where State is not null
State_mapping = df_req.filter(col('State').isNotNull()) \
    .select('Country', 'State') \
    .distinct() \
    .groupBy('Country') \
    .agg(collect_set('State').alias('State_Set'))

# Extract a single State from the set for each Product
State_mapping = State_mapping.withColumn('State_Mapped', col('State_Set')[0])

# Join the original DataFrame with the mapping to fill null values
df_req = df_req.join(State_mapping, on='Country', how='left') \
    .withColumn('State', coalesce(col('State'), col('State_Mapped'))) \
    .drop('State_Set', 'State_Mapped')

# Show the updated DataFrame
#df_req.select(sum(col('State').isNull().cast('int')).alias("State")).show()

# %%
#State_mapping.show()
# Out:
# +---------+--------------------+---------------+
# |  Country|           State_Set|   State_Mapped|
# +---------+--------------------+---------------+
# |  Germany|            [Berlin]|         Berlin|
# |      USA|[Michigan, Vermon...|       Michigan|
# |       UK|           [England]|        England|
# |   Canada|           [Ontario]|        Ontario|
# |Australia|   [New South Wales]|New South Wales|
# +---------+--------------------+---------------+

# %%
# Create a mapping of Product to Product_Brand where Product_Brand is not null
product_brand_mapping = df_req.filter(col('Product_Brand').isNotNull()) \
    .select('products', 'Product_Brand') \
    .distinct() \
    .groupBy('products') \
    .agg(collect_set('Product_Brand').alias('Product_Brand_Set'))

# Extract a single Product_Brand from the set for each Product
product_brand_mapping = product_brand_mapping.withColumn('Product_Brand_Mapped', col('Product_Brand_Set')[0])

# Join the original DataFrame with the mapping to fill null values
df_req = df_req.join(product_brand_mapping, on='products', how='left') \
    .withColumn('Product_Brand', coalesce(col('Product_Brand'), col('Product_Brand_Mapped'))) \
    .drop('Product_Brand_Set', 'Product_Brand_Mapped')

# Show the updated DataFrame
#df_req.select(sum(col('Product_Brand').isNull().cast('int')).alias("Product_Brand")).show()

# %%
#product_brand_mapping.show(318,truncate=False)
# Out:
# +----------------------------+--------------------------------------------+--------------------+
# |products                    |Product_Brand_Set                           |Product_Brand_Mapped|
# +----------------------------+--------------------------------------------+--------------------+
# |4K TV                       |[Sony, Samsung]                             |Sony                |
# |A-line dress                |[Zara]                                      |Zara                |
# |Acer Iconia Tab             |[Apple, Samsung]                            |Apple               |
# |Acer Swift                  |[Apple]                                     |Apple               |
# |Action                      |[HarperCollins]                             |HarperCollins       |
# |Adventure                   |[Penguin Books, Random House, HarperCollins]|Penguin Books       |
# |Affogato                    |[Nestle]                                    |Nestle              |
# |Air conditioner             |[Mitsubhisi]                                |Mitsubhisi          |
# |Alkaline water              |[Pepsi, Coca-Cola]                          |Pepsi               |
# |Amazon Fire Tablet          |[Apple, Samsung]                            |Apple               |
# |Americano                   |[Nestle]                                    |Nestle              |
# |Android TV                  |[Sony, Samsung]                             |Sony                |
# |Anthologies                 |[Random House]                              |Random House        |
# |Apple juice                 |[Pepsi, Coca-Cola]                          |Pepsi               |
# |Art supplies                |[Penguin Books]                             |Penguin Books       |
# |Artesian water              |[Pepsi, Coca-Cola]                          |Pepsi               |
# |Asus ZenBook                |[Apple]                                     |Apple               |
# |Asus ZenPad                 |[Apple, Samsung]                            |Apple               |
# |Athletic shorts             |[Nike]                                      |Nike                |
# |Bathtub                     |[Bed Bath & Beyond]                         |Bed Bath & Beyond   |
# |Bed                         |[IKEA, Home Depot]                          |IKEA                |
# |Bed sheet set               |[Bed Bath & Beyond]                         |Bed Bath & Beyond   |
# |Bed skirt                   |[Bed Bath & Beyond]                         |Bed Bath & Beyond   |
# |Beef jerky                  |[Nestle]                                    |Nestle              |
# |Bermuda shorts              |[Nike]                                      |Nike                |
# |Biography                   |[Penguin Books, Random House, HarperCollins]|Penguin Books       |
# |Black refrigerator          |[Whirepool]                                 |Whirepool           |
# |Blanket                     |[Bed Bath & Beyond]                         |Bed Bath & Beyond   |
# |Blazer                      |[Adidas]                                    |Adidas              |
# |Blender                     |[Bed Bath & Beyond]                         |Bed Bath & Beyond   |
# |Blouse                      |[Zara]                                      |Zara                |
# |Bluetooth headphones        |[Sony]                                      |Sony                |
# |Board shorts                |[Nike]                                      |Nike                |
# |Bodycon dress               |[Zara]                                      |Zara                |
# |Bomber jacket               |[Adidas]                                    |Adidas              |
# |Books                       |[Penguin Books]                             |Penguin Books       |
# |Bookshelf                   |[IKEA, Home Depot]                          |IKEA                |
# |Bootcut jeans               |[Zara]                                      |Zara                |
# |Boots                       |[Adidas, Nike]                              |Adidas              |
# |Bottled water               |[Pepsi, Coca-Cola]                          |Pepsi               |
# |Bottom-freezer refrigerator |[Whirepool]                                 |Whirepool           |
# |Boyfriend jeans             |[Zara]                                      |Zara                |
# |Building blocks             |[Penguin Books]                             |Penguin Books       |
# |Business                    |[Penguin Books, Random House, HarperCollins]|Penguin Books       |
# |Button-down shirt           |[Zara]                                      |Zara                |
# |Candles                     |[IKEA, Home Depot]                          |IKEA                |
# |Cappuccino                  |[Nestle]                                    |Nestle              |
# |Cargo shorts                |[Nike]                                      |Nike                |
# |Cassette AC                 |[Mitsubhisi, BlueStar]                      |Mitsubhisi          |
# |Casual dress                |[Zara]                                      |Zara                |
# |Caulking gun                |[Home Depot]                                |Home Depot          |
# |Ceiling lights              |[IKEA]                                      |IKEA                |
# |Central AC                  |[Mitsubhisi, BlueStar]                      |Mitsubhisi          |
# |Chandeliers                 |[IKEA]                                      |IKEA                |
# |Cheese snacks               |[Nestle]                                    |Nestle              |
# |Chino shorts                |[Nike]                                      |Nike                |
# |Chips                       |[Nestle]                                    |Nestle              |
# |Chocolate bars              |[Nestle]                                    |Nestle              |
# |Chocolate cookies           |[Nestle]                                    |Nestle              |
# |Chocolate fondue            |[Nestle]                                    |Nestle              |
# |Chocolate mousse            |[Nestle]                                    |Nestle              |
# |Chocolate-covered fruits    |[Nestle]                                    |Nestle              |
# |Chocolate-covered nuts      |[Nestle]                                    |Nestle              |
# |Classic literature          |[Random House]                              |Random House        |
# |Clocks                      |[IKEA, Home Depot]                          |IKEA                |
# |Clothing                    |[Penguin Books]                             |Penguin Books       |
# |Cocktail dress              |[Zara]                                      |Zara                |
# |Coconut water               |[Pepsi, Coca-Cola]                          |Pepsi               |
# |Coffee beans                |[Nestle]                                    |Nestle              |
# |Coffee maker                |[Bed Bath & Beyond]                         |Bed Bath & Beyond   |
# |Coffee table                |[IKEA, Home Depot]                          |IKEA                |
# |Cola                        |[Pepsi, Coca-Cola]                          |Pepsi               |
# |Comforter                   |[Bed Bath & Beyond]                         |Bed Bath & Beyond   |
# |Compact refrigerator        |[Whirepool]                                 |Whirepool           |
# |Contemporary literature     |[Random House]                              |Random House        |
# |Cooking                     |[Penguin Books, Random House, HarperCollins]|Penguin Books       |
# |Counter-depth refrigerator  |[Whirepool]                                 |Whirepool           |
# |Crackers                    |[Nestle]                                    |Nestle              |
# |Cranberry juice             |[Pepsi, Coca-Cola]                          |Pepsi               |
# |Cream soda                  |[Pepsi, Coca-Cola]                          |Pepsi               |
# |Crew neck tee               |[Adidas, Nike]                              |Adidas              |
# |Crime                       |[HarperCollins]                             |HarperCollins       |
# |Crop top                    |[Adidas, Nike]                              |Adidas              |
# |Cropped jeans               |[Zara]                                      |Zara                |
# |Curtains                    |[IKEA, Home Depot]                          |IKEA                |
# |Curved TV                   |[Sony, Samsung]                             |Sony                |
# |Cycling shorts              |[Nike]                                      |Nike                |
# |DJ headphones               |[Sony]                                      |Sony                |
# |Dark chocolate              |[Nestle]                                    |Nestle              |
# |Decorative pillows          |[IKEA, Home Depot]                          |IKEA                |
# |Dell XPS                    |[Apple]                                     |Apple               |
# |Denim jacket                |[Adidas]                                    |Adidas              |
# |Denim shorts                |[Nike]                                      |Nike                |
# |Desk                        |[IKEA, Home Depot]                          |IKEA                |
# |Desk lamps                  |[IKEA]                                      |IKEA                |
# |Detective                   |[HarperCollins]                             |HarperCollins       |
# |Dining table                |[IKEA, Home Depot]                          |IKEA                |
# |Dishwasher                  |[Bed Bath & Beyond]                         |Bed Bath & Beyond   |
# |Distilled water             |[Pepsi, Coca-Cola]                          |Pepsi               |
# |Distressed jeans            |[Zara]                                      |Zara                |
# |Drama                       |[Random House]                              |Random House        |
# |Dress shirt                 |[Zara]                                      |Zara                |
# |Dresser                     |[IKEA, Home Depot]                          |IKEA                |
# |Drill                       |[Home Depot]                                |Home Depot          |
# |Ductless AC                 |[Mitsubhisi, BlueStar]                      |Mitsubhisi          |
# |Dust ruffle                 |[Bed Bath & Beyond]                         |Bed Bath & Beyond   |
# |Duvet cover                 |[Bed Bath & Beyond]                         |Bed Bath & Beyond   |
# |Dystopian                   |[Penguin Books, Random House, HarperCollins]|Penguin Books       |
# |Educational kits            |[Penguin Books]                             |Penguin Books       |
# |Electric kettle             |[Bed Bath & Beyond]                         |Bed Bath & Beyond   |
# |Energy drink                |[Pepsi, Coca-Cola]                          |Pepsi               |
# |Espadrilles                 |[Adidas, Nike]                              |Adidas              |
# |Espresso                    |[Nestle]                                    |Nestle              |
# |Essays                      |[Random House]                              |Random House        |
# |Fantasy                     |[Penguin Books, Random House, HarperCollins]|Penguin Books       |
# |Fit and flare dress         |[Zara]                                      |Zara                |
# |Flannel shirt               |[Zara]                                      |Zara                |
# |Flare jeans                 |[Zara]                                      |Zara                |
# |Flavored water              |[Pepsi, Coca-Cola]                          |Pepsi               |
# |Flip flops                  |[Adidas, Nike]                              |Adidas              |
# |Floor lamps                 |[IKEA]                                      |IKEA                |
# |Floor-standing AC           |[Mitsubhisi, BlueStar]                      |Mitsubhisi          |
# |Food processor              |[Bed Bath & Beyond]                         |Bed Bath & Beyond   |
# |French door refrigerator    |[Whirepool]                                 |Whirepool           |
# |Fruit punch                 |[Pepsi, Coca-Cola]                          |Pepsi               |
# |Fruit snacks                |[Nestle]                                    |Nestle              |
# |Games                       |[Penguin Books]                             |Penguin Books       |
# |Gaming headphones           |[Sony]                                      |Sony                |
# |Ginger ale                  |[Pepsi, Coca-Cola]                          |Pepsi               |
# |Google Pixel                |[Sony, Apple, Samsung]                      |Sony                |
# |Google Pixel Slate          |[Apple, Samsung]                            |Apple               |
# |Granola bars                |[Nestle]                                    |Nestle              |
# |Grape juice                 |[Pepsi, Coca-Cola]                          |Pepsi               |
# |Grape soda                  |[Pepsi, Coca-Cola]                          |Pepsi               |
# |Grapefruit juice            |[Pepsi, Coca-Cola]                          |Pepsi               |
# |Graphic tee                 |[Adidas, Nike]                              |Adidas              |
# |Ground coffee               |[Nestle]                                    |Nestle              |
# |HDR TV                      |[Samsung, Sony]                             |Samsung             |
# |HP Spectre                  |[Apple]                                     |Apple               |
# |Hammer                      |[Home Depot]                                |Home Depot          |
# |Health                      |[Penguin Books, Random House, HarperCollins]|Penguin Books       |
# |Henley shirt                |[Zara]                                      |Zara                |
# |Henley tee                  |[Adidas, Nike]                              |Adidas              |
# |High heels                  |[Adidas, Nike]                              |Adidas              |
# |High-waisted jeans          |[Zara]                                      |Zara                |
# |Historical fiction          |[Penguin Books, Random House, HarperCollins]|Penguin Books       |
# |History                     |[Penguin Books, Random House, HarperCollins]|Penguin Books       |
# |Hoodie                      |[Zara]                                      |Zara                |
# |Horror                      |[Penguin Books, Random House, HarperCollins]|Penguin Books       |
# |Huawei MediaPad             |[Apple, Samsung]                            |Apple               |
# |Huawei P                    |[Sony, Apple, Samsung]                      |Sony                |
# |Iced tea                    |[Pepsi, Coca-Cola]                          |Pepsi               |
# |In-ear headphones           |[Sony]                                      |Sony                |
# |Instant coffee              |[Nestle]                                    |Nestle              |
# |Inverter AC                 |[Mitsubhisi, BlueStar]                      |Mitsubhisi          |
# |Khaki shorts                |[Nike]                                      |Nike                |
# |LCD TV                      |[Sony, Samsung]                             |Sony                |
# |LED TV                      |[Samsung, Sony]                             |Samsung             |
# |LG G                        |[Sony, Apple, Samsung]                      |Sony                |
# |LG Gram                     |[Apple]                                     |Apple               |
# |Latte                       |[Nestle]                                    |Nestle              |
# |Leather jacket              |[Adidas]                                    |Adidas              |
# |Legal thriller              |[HarperCollins]                             |HarperCollins       |
# |Lemon-lime soda             |[Pepsi, Coca-Cola]                          |Pepsi               |
# |Lenovo Tab                  |[Apple, Samsung]                            |Apple               |
# |Lenovo ThinkPad             |[Apple]                                     |Apple               |
# |Level                       |[Home Depot]                                |Home Depot          |
# |Literary fiction            |[Penguin Books, Random House, HarperCollins]|Penguin Books       |
# |Loafers                     |[Adidas, Nike]                              |Adidas              |
# |Long-sleeve tee             |[Adidas, Nike]                              |Adidas              |
# |Low-rise jeans              |[Zara]                                      |Zara                |
# |MacBook                     |[Apple]                                     |Apple               |
# |Macchiato                   |[Nestle]                                    |Nestle              |
# |Mango juice                 |[Pepsi, Coca-Cola]                          |Pepsi               |
# |Mattress topper             |[Bed Bath & Beyond]                         |Bed Bath & Beyond   |
# |Maxi dress                  |[Zara]                                      |Zara                |
# |Memoir                      |[Penguin Books, Random House, HarperCollins]|Penguin Books       |
# |Microsoft Surface           |[Apple, Samsung]                            |Apple               |
# |Microsoft Surface Laptop    |[Apple]                                     |Apple               |
# |Microwave                   |[Bed Bath & Beyond]                         |Bed Bath & Beyond   |
# |Milk chocolate              |[Nestle]                                    |Nestle              |
# |Mineral water               |[Pepsi, Coca-Cola]                          |Pepsi               |
# |Mini fridge                 |[Whirepool]                                 |Whirepool           |
# |Mini-split AC               |[Mitsubhisi, BlueStar]                      |Mitsubhisi          |
# |Mirror                      |[Bed Bath & Beyond]                         |Bed Bath & Beyond   |
# |Mirrors                     |[IKEA, Home Depot]                          |IKEA                |
# |Mixed fruit juice           |[Pepsi, Coca-Cola]                          |Pepsi               |
# |Mocha                       |[Nestle]                                    |Nestle              |
# |Modern literature           |[Random House]                              |Random House        |
# |Motorola Moto               |[Samsung, Apple, Sony]                      |Samsung             |
# |Mystery                     |[Penguin Books, Random House, HarperCollins]|Penguin Books       |
# |Nightstand                  |[IKEA, Home Depot]                          |IKEA                |
# |Noise-cancelling headphones |[Sony]                                      |Sony                |
# |Nokia                       |[Sony, Apple, Samsung]                      |Sony                |
# |Non-fiction literature      |[Random House]                              |Random House        |
# |Nuts                        |[Nestle]                                    |Nestle              |
# |OLED TV                     |[Sony, Samsung]                             |Sony                |
# |Off-the-shoulder tee        |[Adidas, Nike]                              |Adidas              |
# |On-ear headphones           |[Sony]                                      |Sony                |
# |OnePlus                     |[Sony, Apple, Samsung]                      |Sony                |
# |Orange juice                |[Pepsi, Coca-Cola]                          |Pepsi               |
# |Orange soda                 |[Pepsi, Coca-Cola]                          |Pepsi               |
# |Oven                        |[Bed Bath & Beyond]                         |Bed Bath & Beyond   |
# |Over-ear headphones         |[Sony]                                      |Sony                |
# |Oxfords                     |[Adidas, Nike]                              |Adidas              |
# |Package AC                  |[BlueStar]                                  |BlueStar            |
# |Parka                       |[Adidas]                                    |Adidas              |
# |Peacoat                     |[Adidas]                                    |Adidas              |
# |Pendant lights              |[IKEA]                                      |IKEA                |
# |Picture frames              |[IKEA, Home Depot]                          |IKEA                |
# |Pillowcase set              |[Bed Bath & Beyond]                         |Bed Bath & Beyond   |
# |Pineapple juice             |[Pepsi, Coca-Cola]                          |Pepsi               |
# |Plain tee                   |[Adidas, Nike]                              |Adidas              |
# |Plasma TV                   |[Samsung, Sony]                             |Samsung             |
# |Pliers                      |[Home Depot]                                |Home Depot          |
# |Plush toys                  |[Penguin Books]                             |Penguin Books       |
# |Poetry                      |[Random House]                              |Random House        |
# |Political thriller          |[HarperCollins]                             |HarperCollins       |
# |Polo shirt                  |[Zara]                                      |Zara                |
# |Pomegranate juice           |[Pepsi, Coca-Cola]                          |Pepsi               |
# |Popcorn                     |[Nestle]                                    |Nestle              |
# |Portable AC                 |[Mitsubhisi, BlueStar]                      |Mitsubhisi          |
# |Pretzels                    |[Nestle]                                    |Nestle              |
# |Psychological thriller      |[HarperCollins]                             |HarperCollins       |
# |Psychology                  |[Penguin Books, Random House, HarperCollins]|Penguin Books       |
# |Puffer jacket               |[Adidas]                                    |Adidas              |
# |Purified water              |[Pepsi, Coca-Cola]                          |Pepsi               |
# |Puzzles                     |[Penguin Books]                             |Penguin Books       |
# |QLED TV                     |[Sony, Samsung]                             |Sony                |
# |Quilt                       |[Bed Bath & Beyond]                         |Bed Bath & Beyond   |
# |Raglan tee                  |[Adidas, Nike]                              |Adidas              |
# |Razer Blade                 |[Apple]                                     |Apple               |
# |Recessed lighting           |[IKEA]                                      |IKEA                |
# |Refrigerator                |[Bed Bath & Beyond]                         |Bed Bath & Beyond   |
# |Romance                     |[Penguin Books, Random House, HarperCollins]|Penguin Books       |
# |Root beer                   |[Pepsi, Coca-Cola]                          |Pepsi               |
# |Rugs                        |[IKEA, Home Depot]                          |IKEA                |
# |Running shoes               |[Adidas, Nike]                              |Adidas              |
# |Samsung Galaxy              |[Samsung, Apple, Sony]                      |Samsung             |
# |Samsung Galaxy Tab          |[Apple, Samsung]                            |Apple               |
# |Samsung Notebook            |[Apple]                                     |Apple               |
# |Sandals                     |[Adidas, Nike]                              |Adidas              |
# |Saw                         |[Home Depot]                                |Home Depot          |
# |Science                     |[Penguin Books, Random House, HarperCollins]|Penguin Books       |
# |Science fiction             |[Penguin Books, Random House, HarperCollins]|Penguin Books       |
# |Scoop neck tee              |[Adidas, Nike]                              |Adidas              |
# |Screwdriver set             |[Home Depot]                                |Home Depot          |
# |Sculptures                  |[IKEA, Home Depot]                          |IKEA                |
# |Self-help                   |[Penguin Books, Random House, HarperCollins]|Penguin Books       |
# |Sheath dress                |[Zara]                                      |Zara                |
# |Shift dress                 |[Zara]                                      |Zara                |
# |Short stories               |[Random House]                              |Random House        |
# |Shower                      |[Bed Bath & Beyond]                         |Bed Bath & Beyond   |
# |Shower curtain              |[Bed Bath & Beyond]                         |Bed Bath & Beyond   |
# |Side-by-side refrigerator   |[Whirepool]                                 |Whirepool           |
# |Sink                        |[Bed Bath & Beyond]                         |Bed Bath & Beyond   |
# |Skinny jeans                |[Zara]                                      |Zara                |
# |Skorts                      |[Nike]                                      |Nike                |
# |Slippers                    |[Adidas, Nike]                              |Adidas              |
# |Smart TV                    |[Sony, Samsung]                             |Sony                |
# |Smart refrigerator          |[Whirepool]                                 |Whirepool           |
# |Sneakers                    |[Adidas, Nike]                              |Adidas              |
# |Soap dispenser              |[Bed Bath & Beyond]                         |Bed Bath & Beyond   |
# |Sofa                        |[IKEA, Home Depot]                          |IKEA                |
# |Sony Xperia                 |[Samsung, Apple, Sony]                      |Samsung             |
# |Sony Xperia Tablet          |[Apple, Samsung]                            |Apple               |
# |Sparkling water             |[Pepsi, Coca-Cola]                          |Pepsi               |
# |Split AC                    |[Mitsubhisi, BlueStar]                      |Mitsubhisi          |
# |Sports equipment            |[Penguin Books]                             |Penguin Books       |
# |Sports headphones           |[Sony]                                      |Sony                |
# |Spring water                |[Pepsi, Coca-Cola]                          |Pepsi               |
# |Stainless steel refrigerator|[Whirepool]                                 |Whirepool           |
# |Stove                       |[Bed Bath & Beyond]                         |Bed Bath & Beyond   |
# |Straight-leg jeans          |[Zara]                                      |Zara                |
# |Studio headphones           |[Sony]                                      |Sony                |
# |Sundress                    |[Zara]                                      |Zara                |
# |Suspense                    |[HarperCollins]                             |HarperCollins       |
# |Sweatshirt                  |[Zara]                                      |Zara                |
# |Swim trunks                 |[Nike]                                      |Nike                |
# |T-shirt                     |[Zara]                                      |Zara                |
# |TV stand                    |[IKEA, Home Depot]                          |IKEA                |
# |Table lamps                 |[IKEA]                                      |IKEA                |
# |Tank top                    |[Zara]                                      |Zara                |
# |Tape measure                |[Home Depot]                                |Home Depot          |
# |Techno-thriller             |[HarperCollins]                             |HarperCollins       |
# |Thriller                    |[Penguin Books, Random House, HarperCollins]|Penguin Books       |
# |Throw pillow                |[Bed Bath & Beyond]                         |Bed Bath & Beyond   |
# |Toaster                     |[Bed Bath & Beyond]                         |Bed Bath & Beyond   |
# |Toilet                      |[Bed Bath & Beyond]                         |Bed Bath & Beyond   |
# |Toilet paper holder         |[Bed Bath & Beyond]                         |Bed Bath & Beyond   |
# |Tomato juice                |[Pepsi, Coca-Cola]                          |Pepsi               |
# |Toothbrush holder           |[Bed Bath & Beyond]                         |Bed Bath & Beyond   |
# |Top-freezer refrigerator    |[Whirepool]                                 |Whirepool           |
# |Towel rack                  |[Bed Bath & Beyond]                         |Bed Bath & Beyond   |
# |Toys                        |[Penguin Books]                             |Penguin Books       |
# |Track lighting              |[IKEA]                                      |IKEA                |
# |Trail mix                   |[Nestle]                                    |Nestle              |
# |Travel                      |[Penguin Books, Random House, HarperCollins]|Penguin Books       |
# |Trench coat                 |[Adidas]                                    |Adidas              |
# |Truffles                    |[Nestle]                                    |Nestle              |
# |Under cabinet lighting      |[IKEA]                                      |IKEA                |
# |Utility knife               |[Home Depot]                                |Home Depot          |
# |V-neck tee                  |[Adidas, Nike]                              |Adidas              |
# |Varsity jacket              |[Adidas]                                    |Adidas              |
# |Vases                       |[IKEA, Home Depot]                          |IKEA                |
# |Wall art                    |[IKEA, Home Depot]                          |IKEA                |
# |Wall sconces                |[IKEA]                                      |IKEA                |
# |Wardrobe                    |[IKEA, Home Depot]                          |IKEA                |
# |White chocolate             |[Nestle]                                    |Nestle              |
# |Wide-leg jeans              |[Zara]                                      |Zara                |
# |Windbreaker                 |[Adidas]                                    |Adidas              |
# |Window AC                   |[Mitsubhisi, BlueStar]                      |Mitsubhisi          |
# |Wireless headphones         |[Sony]                                      |Sony                |
# |Wrap dress                  |[Zara]                                      |Zara                |
# |Wrench                      |[Home Depot]                                |Home Depot          |
# |Xiaomi Mi                   |[Samsung, Apple, Sony]                      |Samsung             |
# |iPad                        |[Apple, Samsung]                            |Apple               |
# |iPhone                      |[Samsung, Apple, Sony]                      |Samsung             |
# +----------------------------+--------------------------------------------+--------------------+

# %%
# Create a mapping of Product to Product_Category where Product_Category is not null
product_category_mapping = df_req.filter(col('Product_Category').isNotNull()) \
    .select('products', 'Product_Category') \
    .distinct() \
    .groupBy('products') \
    .agg(collect_set('Product_Category').alias('Product_Category_Set'))

# Extract a single Product_Brand from the set for each Product
product_category_mapping = product_category_mapping.withColumn('Product_Category_Mapped', col('Product_Category_Set')[0])

# Join the original DataFrame with the mapping to fill null values
df_req = df_req.join(product_category_mapping, on='products', how='left') \
    .withColumn('Product_Category', coalesce(col('Product_Category'), col('Product_Category_Mapped'))) \
    .drop('Product_Category_Set', 'Product_Category_Mapped')

# Show count  of null values from updated DataFrame
#df_req.select(sum(col('Product_Category').isNull().cast('int')).alias("Product_Category")).show()

# %%
#product_category_mapping.show(318)
# Out:
# +--------------------+--------------------+-----------------------+
# |            products|Product_Category_Set|Product_Category_Mapped|
# +--------------------+--------------------+-----------------------+
# |               4K TV|       [Electronics]|            Electronics|
# |        A-line dress|          [Clothing]|               Clothing|
# |     Acer Iconia Tab|       [Electronics]|            Electronics|
# |          Acer Swift|       [Electronics]|            Electronics|
# |              Action|             [Books]|                  Books|
# |           Adventure|             [Books]|                  Books|
# |            Affogato|           [Grocery]|                Grocery|
# |     Air conditioner|       [Electronics]|            Electronics|
# |      Alkaline water|           [Grocery]|                Grocery|
# |  Amazon Fire Tablet|       [Electronics]|            Electronics|
# |           Americano|           [Grocery]|                Grocery|
# |          Android TV|       [Electronics]|            Electronics|
# |         Anthologies|             [Books]|                  Books|
# |         Apple juice|           [Grocery]|                Grocery|
# |        Art supplies|             [Books]|                  Books|
# |      Artesian water|           [Grocery]|                Grocery|
# |        Asus ZenBook|       [Electronics]|            Electronics|
# |         Asus ZenPad|       [Electronics]|            Electronics|
# |     Athletic shorts|          [Clothing]|               Clothing|
# |             Bathtub|        [Home Decor]|             Home Decor|
# |                 Bed|        [Home Decor]|             Home Decor|
# |       Bed sheet set|        [Home Decor]|             Home Decor|
# |           Bed skirt|        [Home Decor]|             Home Decor|
# |          Beef jerky|           [Grocery]|                Grocery|
# |      Bermuda shorts|          [Clothing]|               Clothing|
# |           Biography|             [Books]|                  Books|
# |  Black refrigerator|       [Electronics]|            Electronics|
# |             Blanket|        [Home Decor]|             Home Decor|
# |              Blazer|          [Clothing]|               Clothing|
# |             Blender|        [Home Decor]|             Home Decor|
# |              Blouse|          [Clothing]|               Clothing|
# |Bluetooth headphones|       [Electronics]|            Electronics|
# |        Board shorts|          [Clothing]|               Clothing|
# |       Bodycon dress|          [Clothing]|               Clothing|
# |       Bomber jacket|          [Clothing]|               Clothing|
# |               Books|             [Books]|                  Books|
# |           Bookshelf|        [Home Decor]|             Home Decor|
# |       Bootcut jeans|          [Clothing]|               Clothing|
# |               Boots|          [Clothing]|               Clothing|
# |       Bottled water|           [Grocery]|                Grocery|
# |Bottom-freezer re...|       [Electronics]|            Electronics|
# |     Boyfriend jeans|          [Clothing]|               Clothing|
# |     Building blocks|             [Books]|                  Books|
# |            Business|             [Books]|                  Books|
# |   Button-down shirt|          [Clothing]|               Clothing|
# |             Candles|        [Home Decor]|             Home Decor|
# |          Cappuccino|           [Grocery]|                Grocery|
# |        Cargo shorts|          [Clothing]|               Clothing|
# |         Cassette AC|       [Electronics]|            Electronics|
# |        Casual dress|          [Clothing]|               Clothing|
# |        Caulking gun|        [Home Decor]|             Home Decor|
# |      Ceiling lights|        [Home Decor]|             Home Decor|
# |          Central AC|       [Electronics]|            Electronics|
# |         Chandeliers|        [Home Decor]|             Home Decor|
# |       Cheese snacks|           [Grocery]|                Grocery|
# |        Chino shorts|          [Clothing]|               Clothing|
# |               Chips|           [Grocery]|                Grocery|
# |      Chocolate bars|           [Grocery]|                Grocery|
# |   Chocolate cookies|           [Grocery]|                Grocery|
# |    Chocolate fondue|           [Grocery]|                Grocery|
# |    Chocolate mousse|           [Grocery]|                Grocery|
# |Chocolate-covered...|           [Grocery]|                Grocery|
# |Chocolate-covered...|           [Grocery]|                Grocery|
# |  Classic literature|             [Books]|                  Books|
# |              Clocks|        [Home Decor]|             Home Decor|
# |            Clothing|             [Books]|                  Books|
# |      Cocktail dress|          [Clothing]|               Clothing|
# |       Coconut water|           [Grocery]|                Grocery|
# |        Coffee beans|           [Grocery]|                Grocery|
# |        Coffee maker|        [Home Decor]|             Home Decor|
# |        Coffee table|        [Home Decor]|             Home Decor|
# |                Cola|           [Grocery]|                Grocery|
# |           Comforter|        [Home Decor]|             Home Decor|
# |Compact refrigerator|       [Electronics]|            Electronics|
# |Contemporary lite...|             [Books]|                  Books|
# |             Cooking|             [Books]|                  Books|
# |Counter-depth ref...|       [Electronics]|            Electronics|
# |            Crackers|           [Grocery]|                Grocery|
# |     Cranberry juice|           [Grocery]|                Grocery|
# |          Cream soda|           [Grocery]|                Grocery|
# |       Crew neck tee|          [Clothing]|               Clothing|
# |               Crime|             [Books]|                  Books|
# |            Crop top|          [Clothing]|               Clothing|
# |       Cropped jeans|          [Clothing]|               Clothing|
# |            Curtains|        [Home Decor]|             Home Decor|
# |           Curved TV|       [Electronics]|            Electronics|
# |      Cycling shorts|          [Clothing]|               Clothing|
# |       DJ headphones|       [Electronics]|            Electronics|
# |      Dark chocolate|           [Grocery]|                Grocery|
# |  Decorative pillows|        [Home Decor]|             Home Decor|
# |            Dell XPS|       [Electronics]|            Electronics|
# |        Denim jacket|          [Clothing]|               Clothing|
# |        Denim shorts|          [Clothing]|               Clothing|
# |                Desk|        [Home Decor]|             Home Decor|
# |          Desk lamps|        [Home Decor]|             Home Decor|
# |           Detective|             [Books]|                  Books|
# |        Dining table|        [Home Decor]|             Home Decor|
# |          Dishwasher|        [Home Decor]|             Home Decor|
# |     Distilled water|           [Grocery]|                Grocery|
# |    Distressed jeans|          [Clothing]|               Clothing|
# |               Drama|             [Books]|                  Books|
# |         Dress shirt|          [Clothing]|               Clothing|
# |             Dresser|        [Home Decor]|             Home Decor|
# |               Drill|        [Home Decor]|             Home Decor|
# |         Ductless AC|       [Electronics]|            Electronics|
# |         Dust ruffle|        [Home Decor]|             Home Decor|
# |         Duvet cover|        [Home Decor]|             Home Decor|
# |           Dystopian|             [Books]|                  Books|
# |    Educational kits|             [Books]|                  Books|
# |     Electric kettle|        [Home Decor]|             Home Decor|
# |        Energy drink|           [Grocery]|                Grocery|
# |         Espadrilles|          [Clothing]|               Clothing|
# |            Espresso|           [Grocery]|                Grocery|
# |              Essays|             [Books]|                  Books|
# |             Fantasy|             [Books]|                  Books|
# | Fit and flare dress|          [Clothing]|               Clothing|
# |       Flannel shirt|          [Clothing]|               Clothing|
# |         Flare jeans|          [Clothing]|               Clothing|
# |      Flavored water|           [Grocery]|                Grocery|
# |          Flip flops|          [Clothing]|               Clothing|
# |         Floor lamps|        [Home Decor]|             Home Decor|
# |   Floor-standing AC|       [Electronics]|            Electronics|
# |      Food processor|        [Home Decor]|             Home Decor|
# |French door refri...|       [Electronics]|            Electronics|
# |         Fruit punch|           [Grocery]|                Grocery|
# |        Fruit snacks|           [Grocery]|                Grocery|
# |               Games|             [Books]|                  Books|
# |   Gaming headphones|       [Electronics]|            Electronics|
# |          Ginger ale|           [Grocery]|                Grocery|
# |        Google Pixel|       [Electronics]|            Electronics|
# |  Google Pixel Slate|       [Electronics]|            Electronics|
# |        Granola bars|           [Grocery]|                Grocery|
# |         Grape juice|           [Grocery]|                Grocery|
# |          Grape soda|           [Grocery]|                Grocery|
# |    Grapefruit juice|           [Grocery]|                Grocery|
# |         Graphic tee|          [Clothing]|               Clothing|
# |       Ground coffee|           [Grocery]|                Grocery|
# |              HDR TV|       [Electronics]|            Electronics|
# |          HP Spectre|       [Electronics]|            Electronics|
# |              Hammer|        [Home Decor]|             Home Decor|
# |              Health|             [Books]|                  Books|
# |        Henley shirt|          [Clothing]|               Clothing|
# |          Henley tee|          [Clothing]|               Clothing|
# |          High heels|          [Clothing]|               Clothing|
# |  High-waisted jeans|          [Clothing]|               Clothing|
# |  Historical fiction|             [Books]|                  Books|
# |             History|             [Books]|                  Books|
# |              Hoodie|          [Clothing]|               Clothing|
# |              Horror|             [Books]|                  Books|
# |     Huawei MediaPad|       [Electronics]|            Electronics|
# |            Huawei P|       [Electronics]|            Electronics|
# |            Iced tea|           [Grocery]|                Grocery|
# |   In-ear headphones|       [Electronics]|            Electronics|
# |      Instant coffee|           [Grocery]|                Grocery|
# |         Inverter AC|       [Electronics]|            Electronics|
# |        Khaki shorts|          [Clothing]|               Clothing|
# |              LCD TV|       [Electronics]|            Electronics|
# |              LED TV|       [Electronics]|            Electronics|
# |                LG G|       [Electronics]|            Electronics|
# |             LG Gram|       [Electronics]|            Electronics|
# |               Latte|           [Grocery]|                Grocery|
# |      Leather jacket|          [Clothing]|               Clothing|
# |      Legal thriller|             [Books]|                  Books|
# |     Lemon-lime soda|           [Grocery]|                Grocery|
# |          Lenovo Tab|       [Electronics]|            Electronics|
# |     Lenovo ThinkPad|       [Electronics]|            Electronics|
# |               Level|        [Home Decor]|             Home Decor|
# |    Literary fiction|             [Books]|                  Books|
# |             Loafers|          [Clothing]|               Clothing|
# |     Long-sleeve tee|          [Clothing]|               Clothing|
# |      Low-rise jeans|          [Clothing]|               Clothing|
# |             MacBook|       [Electronics]|            Electronics|
# |           Macchiato|           [Grocery]|                Grocery|
# |         Mango juice|           [Grocery]|                Grocery|
# |     Mattress topper|        [Home Decor]|             Home Decor|
# |          Maxi dress|          [Clothing]|               Clothing|
# |              Memoir|             [Books]|                  Books|
# |   Microsoft Surface|       [Electronics]|            Electronics|
# |Microsoft Surface...|       [Electronics]|            Electronics|
# |           Microwave|        [Home Decor]|             Home Decor|
# |      Milk chocolate|           [Grocery]|                Grocery|
# |       Mineral water|           [Grocery]|                Grocery|
# |         Mini fridge|       [Electronics]|            Electronics|
# |       Mini-split AC|       [Electronics]|            Electronics|
# |              Mirror|        [Home Decor]|             Home Decor|
# |             Mirrors|        [Home Decor]|             Home Decor|
# |   Mixed fruit juice|           [Grocery]|                Grocery|
# |               Mocha|           [Grocery]|                Grocery|
# |   Modern literature|             [Books]|                  Books|
# |       Motorola Moto|       [Electronics]|            Electronics|
# |             Mystery|             [Books]|                  Books|
# |          Nightstand|        [Home Decor]|             Home Decor|
# |Noise-cancelling ...|       [Electronics]|            Electronics|
# |               Nokia|       [Electronics]|            Electronics|
# |Non-fiction liter...|             [Books]|                  Books|
# |                Nuts|           [Grocery]|                Grocery|
# |             OLED TV|       [Electronics]|            Electronics|
# |Off-the-shoulder tee|          [Clothing]|               Clothing|
# |   On-ear headphones|       [Electronics]|            Electronics|
# |             OnePlus|       [Electronics]|            Electronics|
# |        Orange juice|           [Grocery]|                Grocery|
# |         Orange soda|           [Grocery]|                Grocery|
# |                Oven|        [Home Decor]|             Home Decor|
# | Over-ear headphones|       [Electronics]|            Electronics|
# |             Oxfords|          [Clothing]|               Clothing|
# |          Package AC|       [Electronics]|            Electronics|
# |               Parka|          [Clothing]|               Clothing|
# |             Peacoat|          [Clothing]|               Clothing|
# |      Pendant lights|        [Home Decor]|             Home Decor|
# |      Picture frames|        [Home Decor]|             Home Decor|
# |      Pillowcase set|        [Home Decor]|             Home Decor|
# |     Pineapple juice|           [Grocery]|                Grocery|
# |           Plain tee|          [Clothing]|               Clothing|
# |           Plasma TV|       [Electronics]|            Electronics|
# |              Pliers|        [Home Decor]|             Home Decor|
# |          Plush toys|             [Books]|                  Books|
# |              Poetry|             [Books]|                  Books|
# |  Political thriller|             [Books]|                  Books|
# |          Polo shirt|          [Clothing]|               Clothing|
# |   Pomegranate juice|           [Grocery]|                Grocery|
# |             Popcorn|           [Grocery]|                Grocery|
# |         Portable AC|       [Electronics]|            Electronics|
# |            Pretzels|           [Grocery]|                Grocery|
# |Psychological thr...|             [Books]|                  Books|
# |          Psychology|             [Books]|                  Books|
# |       Puffer jacket|          [Clothing]|               Clothing|
# |      Purified water|           [Grocery]|                Grocery|
# |             Puzzles|             [Books]|                  Books|
# |             QLED TV|       [Electronics]|            Electronics|
# |               Quilt|        [Home Decor]|             Home Decor|
# |          Raglan tee|          [Clothing]|               Clothing|
# |         Razer Blade|       [Electronics]|            Electronics|
# |   Recessed lighting|        [Home Decor]|             Home Decor|
# |        Refrigerator|        [Home Decor]|             Home Decor|
# |             Romance|             [Books]|                  Books|
# |           Root beer|           [Grocery]|                Grocery|
# |                Rugs|        [Home Decor]|             Home Decor|
# |       Running shoes|          [Clothing]|               Clothing|
# |      Samsung Galaxy|       [Electronics]|            Electronics|
# |  Samsung Galaxy Tab|       [Electronics]|            Electronics|
# |    Samsung Notebook|       [Electronics]|            Electronics|
# |             Sandals|          [Clothing]|               Clothing|
# |                 Saw|        [Home Decor]|             Home Decor|
# |             Science|             [Books]|                  Books|
# |     Science fiction|             [Books]|                  Books|
# |      Scoop neck tee|          [Clothing]|               Clothing|
# |     Screwdriver set|        [Home Decor]|             Home Decor|
# |          Sculptures|        [Home Decor]|             Home Decor|
# |           Self-help|             [Books]|                  Books|
# |        Sheath dress|          [Clothing]|               Clothing|
# |         Shift dress|          [Clothing]|               Clothing|
# |       Short stories|             [Books]|                  Books|
# |              Shower|        [Home Decor]|             Home Decor|
# |      Shower curtain|        [Home Decor]|             Home Decor|
# |Side-by-side refr...|       [Electronics]|            Electronics|
# |                Sink|        [Home Decor]|             Home Decor|
# |        Skinny jeans|          [Clothing]|               Clothing|
# |              Skorts|          [Clothing]|               Clothing|
# |            Slippers|          [Clothing]|               Clothing|
# |            Smart TV|       [Electronics]|            Electronics|
# |  Smart refrigerator|       [Electronics]|            Electronics|
# |            Sneakers|          [Clothing]|               Clothing|
# |      Soap dispenser|        [Home Decor]|             Home Decor|
# |                Sofa|        [Home Decor]|             Home Decor|
# |         Sony Xperia|       [Electronics]|            Electronics|
# |  Sony Xperia Tablet|       [Electronics]|            Electronics|
# |     Sparkling water|           [Grocery]|                Grocery|
# |            Split AC|       [Electronics]|            Electronics|
# |    Sports equipment|             [Books]|                  Books|
# |   Sports headphones|       [Electronics]|            Electronics|
# |        Spring water|           [Grocery]|                Grocery|
# |Stainless steel r...|       [Electronics]|            Electronics|
# |               Stove|        [Home Decor]|             Home Decor|
# |  Straight-leg jeans|          [Clothing]|               Clothing|
# |   Studio headphones|       [Electronics]|            Electronics|
# |            Sundress|          [Clothing]|               Clothing|
# |            Suspense|             [Books]|                  Books|
# |          Sweatshirt|          [Clothing]|               Clothing|
# |         Swim trunks|          [Clothing]|               Clothing|
# |             T-shirt|          [Clothing]|               Clothing|
# |            TV stand|        [Home Decor]|             Home Decor|
# |         Table lamps|        [Home Decor]|             Home Decor|
# |            Tank top|          [Clothing]|               Clothing|
# |        Tape measure|        [Home Decor]|             Home Decor|
# |     Techno-thriller|             [Books]|                  Books|
# |            Thriller|             [Books]|                  Books|
# |        Throw pillow|        [Home Decor]|             Home Decor|
# |             Toaster|        [Home Decor]|             Home Decor|
# |              Toilet|        [Home Decor]|             Home Decor|
# | Toilet paper holder|        [Home Decor]|             Home Decor|
# |        Tomato juice|           [Grocery]|                Grocery|
# |   Toothbrush holder|        [Home Decor]|             Home Decor|
# |Top-freezer refri...|       [Electronics]|            Electronics|
# |          Towel rack|        [Home Decor]|             Home Decor|
# |                Toys|             [Books]|                  Books|
# |      Track lighting|        [Home Decor]|             Home Decor|
# |           Trail mix|           [Grocery]|                Grocery|
# |              Travel|             [Books]|                  Books|
# |         Trench coat|          [Clothing]|               Clothing|
# |            Truffles|           [Grocery]|                Grocery|
# |Under cabinet lig...|        [Home Decor]|             Home Decor|
# |       Utility knife|        [Home Decor]|             Home Decor|
# |          V-neck tee|          [Clothing]|               Clothing|
# |      Varsity jacket|          [Clothing]|               Clothing|
# |               Vases|        [Home Decor]|             Home Decor|
# |            Wall art|        [Home Decor]|             Home Decor|
# |        Wall sconces|        [Home Decor]|             Home Decor|
# |            Wardrobe|        [Home Decor]|             Home Decor|
# |     White chocolate|           [Grocery]|                Grocery|
# |      Wide-leg jeans|          [Clothing]|               Clothing|
# |         Windbreaker|          [Clothing]|               Clothing|
# |           Window AC|       [Electronics]|            Electronics|
# | Wireless headphones|       [Electronics]|            Electronics|
# |          Wrap dress|          [Clothing]|               Clothing|
# |              Wrench|        [Home Decor]|             Home Decor|
# |           Xiaomi Mi|       [Electronics]|            Electronics|
# |                iPad|       [Electronics]|            Electronics|
# |              iPhone|       [Electronics]|            Electronics|
# +--------------------+--------------------+-----------------------+

# %% [markdown]
# #### Handle Null values using mean - ['Age','Ratings']

# %%
# Filling null values by mean
mean_Age = df_req.select(mean("Age")).collect()[0][0]
mean_Ratings = df_req.select(mean("Ratings")).collect()[0][0] #3.166
df_req = df_req.fillna({'Ratings': round(mean_Ratings,0),
                       "Age":round(mean_Age)
                      })

# %% [markdown]
# #### Handle Null values using mode - ['Gender','Income','Customer_Segment','Feedback', 'Shipping_Method', 'Payment_Method']

# %%
mode_df_Income = df_req.groupBy("Income").count().orderBy("count",ascending=0).first()
mode_value_Income = mode_df_Income["Income"] #Medium

mode_df_Gender = df_req.groupBy("Gender").count().orderBy("count",ascending=0).first()
mode_value_Gender = mode_df_Gender["Gender"] # Male

mode_df_Customer_Segment = df_req.groupBy("Customer_Segment").count().orderBy("count",ascending=0).first()
mode_value_Customer_Segment = mode_df_Customer_Segment["Customer_Segment"]

mode_df_Feedback = df_req.groupBy("Feedback").count().orderBy("count",ascending=0).first()
mode_value_Feedback = mode_df_Feedback["Feedback"] # Good

mode_df_Payment_Method = df_req.groupBy("Payment_Method").count().orderBy("count",ascending=0).first()
mode_value_Payment_Method = mode_df_Payment_Method["Payment_Method"]

mode_df_Shipping_Method = df_req.groupBy("Shipping_Method").count().orderBy("count",ascending=0).first()
mode_value_Shipping_Method = mode_df_Shipping_Method["Shipping_Method"]

# %%
# Filling null value with mode value
df_req = df_req.fillna({
                        "Income": mode_value_Income,
                        'Feedback': mode_value_Feedback,
                        "Payment_Method":mode_value_Payment_Method,
                       "Shipping_Method":mode_value_Shipping_Method,
                       "Customer_Segment":mode_value_Customer_Segment,
                       "Gender":mode_value_Gender
                      })

# %% [markdown]
# #### Handle Null values by calculation - ['Total_Purchases', 'Amount', 'Total_Amount']

# %%
# Filling null values in Total_Purchases 
df_req = df_req.withColumn(
    'Total_Purchases',
    when(
        col('Total_Purchases').isNull(),
        col('Total_Amount') / col('Amount')
    ).otherwise(col('Total_Purchases'))
)

# %%
# Filling null values in Amount 
df_req = df_req.withColumn(
    'Amount',
    when(
        col('Amount').isNull(),
        col('Total_Amount') / col('Total_Purchases')
    ).otherwise(col('Amount'))
)

# %%
# Filling null values in Total_Amount 
df_req = df_req.withColumn(
    'Total_Amount',
    when(
        col('Total_Amount').isNull(),
        col('Total_Purchases') * col('Amount')
    ).otherwise(col('Total_Amount'))
)

# %%
# Checking null values
null_count1 = df_req.select([sum(col(c).isNull().cast("int")).alias(c) for c in df_req.columns])
#null_count1.show(vertical=True)

# %%
df_req=df_req.dropna()

# %%
# Checking null values
null_count2 = df_req.select([sum(col(c).isNull().cast("int")).alias(c) for c in df_req.columns])
null_count2.show(vertical=True)
# Out:
# -RECORD 0---------------
#  products         | 0
#  Country          | 0
#  State            | 0
#  Customer_ID      | 0
#  City             | 0
#  Age              | 0
#  Gender           | 0
#  Income           | 0
#  Customer_Segment | 0
#  Date             | 0
#  Total_Purchases  | 0
#  Amount           | 0
#  Total_Amount     | 0
#  Product_Category | 0
#  Product_Brand    | 0
#  Product_Type     | 0
#  Feedback         | 0
#  Shipping_Method  | 0
#  Payment_Method   | 0
#  Ratings          | 0

# %%
print(df_req.columns)
# Out:
# ['products', 'Country', 'State', 'Customer_ID', 'City', 'Age', 'Gender', 'Income', 'Customer_Segment', 'Date', 'Total_Purchases', 'Amount', 'Total_Amount', 'Product_Category', 'Product_Brand', 'Product_Type', 'Feedback', 'Shipping_Method', 'Payment_Method', 'Ratings']

# %%
duplicates_df = df_req.groupBy('products', 'Country', 'State', 'Customer_ID', 'City', 'Age', 'Gender', 'Income', 'Customer_Segment', 'Date', 'Total_Purchases', 'Amount', 'Total_Amount', 'Product_Category', 'Product_Brand', 'Product_Type', 'Feedback', 'Shipping_Method', 'Payment_Method', 'Ratings').count().filter(col("count") > 1)

# Show the resulting DataFrame with duplicates
#duplicates_df.show()

# %% [markdown]
# - We found that there are some duplicate rows. we have to remove duplicates

# %%
# Remove duplicates based on all columns
df_no_duplicates = df_req.dropDuplicates()

# Show the resulting DataFrame
#df_no_duplicates.show()

# %%
#df_no_duplicates.count()
# Out:
# 301336

# %%
df=df_no_duplicates

# %%
# Replace 'USA' with 'United States of America' and 'UK' with 'United Kingdom' in the 'Country' column
df = df.withColumn("Country", 
                   when(col("Country") == "USA", "United States of America")
                   .when(col("Country") == "UK", "United Kingdom")
                   .otherwise(col("Country")))

# %%
df = df.withColumnRenamed("Total_Purchases", "Quantity")

# %%
quantiles = df.approxQuantile("Age", [0.25, 0.75], 0.01)
Q1 = quantiles[0]
Q3 = quantiles[1]

# Calculate IQR
IQR = Q3 - Q1

# Determine bounds for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

print(f"Q1: {Q1}, Q3: {Q3}, IQR: {IQR}")
print(f"Lower Bound: {lower_bound}, Upper Bound: {upper_bound}")

# Identify outliers
outliers = df.filter((col("Age") < lower_bound) | (col("Age") > upper_bound))

# Show the outliers
#outliers.show()
# Out:
# Q1: 22.0, Q3: 46.0, IQR: 24.0
# Lower Bound: -14.0, Upper Bound: 82.0

# %% [markdown]
# ### After doing all Data Cleaning We have 20 Features and 301336 rows

# %% [markdown]
# #### converting date column from in same format yyyy-mm-dd

# %%
df = df.withColumn("Date",trim("Date"))

# %%
# Convert the string date column to a date type using different formats
df = df.withColumn("Date",
                   coalesce(
                       to_date("Date", "MM/dd/yyyy"),
                       to_date("Date", "M/d/yyyy"),
                       to_date("Date", "MM/d/yyyy"),
                       to_date("Date", "M/dd/yyyy")
                   ))

# Format the date column to 'yyyy-MM-dd'
df = df.withColumn("Date", date_format("Date", "yyyy-MM-dd"))

# Show the updated DataFrame
#df.select("Date").show(5)

# %%
import pandas as pd

# %%
df_pd = df.toPandas()

# %%
type(df_pd)
# Out:
# pandas.core.frame.DataFrame

# %%
df_pd['Date'] = pd.to_datetime(df_pd['Date'])
print(df_pd['Date'].dtype)
df_pd["Date"]
# Out:
# datetime64[ns]
# 0        2023-09-18
# 1        2023-03-24
# 2        2023-10-04
# 3        2023-12-28
# 4        2023-06-06
#             ...
# 301331   2023-07-02
# 301332   2023-06-16
# 301333   2024-02-14
# 301334   2023-05-28
# 301335   2024-01-20
# Name: Date, Length: 301336, dtype: datetime64[ns]

# %%
df_pd.to_excel("output.xlsx", index=False)

# %% [markdown]
# ####  uploding dataframe on hive in table format

# %%
#spark.sql("CREATE DATABASE IF NOT EXISTS BigDataProject")
#df.write.mode("overwrite").saveAsTable("BigDataProject.retailTransitionTable")

# %%
#spark.sql("SELECT * FROM BigDataProject.retailTransitionTable").show()

# %%
#df.groupby("Date").agg(sum("Total_Amount").alias("Total_Amount_sum")).count()
# Out:
# 366

# %%
df_t=df_pd

# %%
df_t.head()
# Out:
#          products  Country   State  Customer_ID      City   Age  Gender  \
# 0  Cycling shorts  Germany  Berlin      37249.0  Dortmund  21.0    Male
# 1     Dress shirt  Germany  Berlin      26603.0    Munich  29.0    Male
# 2         Candles  Germany  Berlin      31878.0   Cologne  25.0    Male
# 3           Drill  Germany  Berlin      78484.0   Cologne  19.0  Female
# 4  Flavored water  Germany  Berlin      66989.0   Leipzig  19.0    Male
#
#    Income Customer_Segment       Date  Quantity      Amount  Total_Amount  \
# 0     Low          Regular 2023-09-18       3.0  108.028757    324.086270
# 1  Medium          Premium 2023-03-24       1.0   46.588070     46.588070
# 2  Medium              New 2023-10-04      10.0  397.611229   3976.112295
# 3  Medium              New 2023-12-28       9.0  274.984254   2474.858288
# 4  Medium              New 2023-06-06       2.0   85.717621    171.435242
#
#   Product_Category Product_Brand Product_Type   Feedback Shipping_Method  \
# 0         Clothing          Nike       Shorts  Excellent        Same-Day
# 1         Clothing          Zara        Shirt        Bad        Same-Day
# 2       Home Decor    Home Depot  Decorations  Excellent        Standard
# 3       Home Decor    Home Depot        Tools       Good         Express
# 4          Grocery     Coca-Cola        Water  Excellent        Standard
#
#   Payment_Method  Ratings
# 0     Debit Card      5.0
# 1           Cash      1.0
# 2           Cash      4.0
# 3         PayPal      4.0
# 4     Debit Card      5.0
